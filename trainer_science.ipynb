# %%
import os 
import pandas as pd
import numpy as np
import csv 



path = "data"

# %%
trainers = pd.read_csv("my-collection.csv")

# %%
trainers.columns
# Out:
# Index(['Brand', 'Model', 'Colour', 'Shoe Size (UK 8)', 'Release Date',
#        'Purchase Year', 'Designer', 'Retail Price', 'Cost',
#        'Secondary Market Price (UK8 Stock X)'],
#       dtype='object')

# %%
trainers.head(100)
# Out:
#           Brand         Model           Colour  Shoe Size (UK 8)  \
# 0        Adidas           NMD         Sun Glow               8.0
# 1          Nike    Air Max 1       Varsity Red               8.0
# 2          Nike    Air Max 1   University Blue               8.0
# 3          Nike    Air Max 1     Kiss of Death               8.0
# 4          Nike    Air Max 1    Atmos Elephant               8.0
# ..          ...           ...              ...               ...
# 59  New Balance           997            Multi               7.0
# 60         Vans        SK8 HI            Black               8.0
# 61     Converse  Chuck Taylor            Black               8.0
# 62          NaN  Chuck Taylor            White               8.0
# 63        Yeezy           700               OG               8.0
#
#     Release Date  Purchase Year           Designer Retail Price     Cost  \
# 0         2017.0           2017           Pharrell      £199.00  £350.00
# 1         2017.0           2017                NaN      £120.00  £120.00
# 2         2017.0           2017                NaN      £120.00  £120.00
# 3         2021.0           2021               Clot      £120.00  £195.00
# 4         2015.0           2019              Atmos      £120.00  £270.00
# ..           ...            ...                ...          ...      ...
# 59           NaN           2016                NaN      £130.00   £35.00
# 60           NaN           2016                NaN       £60.00   £35.00
# 61        2019.0           2019  Comme des Garcons       £90.00   £81.00
# 62        2019.0           2019  Comme des Garcons       £90.00   £81.00
# 63        2015.0           2021                NaN      £250.00  £250.00
#
#    Secondary Market Price (UK8 Stock X)
# 0                               £301.00
# 1                               £290.00
# 2                               £356.00
# 3                               £108.00
# 4                               £964.00
# ..                                  ...
# 59                               £89.00
# 60                               £52.00
# 61                              £123.00
# 62                              £130.00
# 63                              £320.00
#
# [64 rows x 10 columns]

# %%
#trainers["Colour"].value_counts() 
trainers["Release Date"].value_counts()
# Out:
# 2020.0    15
# 2019.0    12
# 2018.0    10
# 2021.0     8
# 2017.0     8
# 2015.0     6
# 2010.0     1
# 2016.0     1
# Name: Release Date, dtype: int64

# %%
print(trainers["Secondary Market Price (UK8 Stock X)"])
# Out:
# 0     £301.00
# 1     £290.00
# 2     £356.00
# 3     £108.00
# 4     £964.00
#        ...
# 59     £89.00
# 60     £52.00
# 61    £123.00
# 62    £130.00
# 63    £320.00
# Name: Secondary Market Price (UK8 Stock X), Length: 64, dtype: object

# %%
trainers["Cost"] = trainers["Cost"].str.replace("£","").astype(float)

# %%
trainers.head(100)
# Out:
#           Brand         Model           Colour  Shoe Size (UK 8)  \
# 0        Adidas           NMD         Sun Glow               8.0
# 1          Nike    Air Max 1       Varsity Red               8.0
# 2          Nike    Air Max 1   University Blue               8.0
# 3          Nike    Air Max 1     Kiss of Death               8.0
# 4          Nike    Air Max 1    Atmos Elephant               8.0
# ..          ...           ...              ...               ...
# 59  New Balance           997            Multi               7.0
# 60         Vans        SK8 HI            Black               8.0
# 61     Converse  Chuck Taylor            Black               8.0
# 62          NaN  Chuck Taylor            White               8.0
# 63        Yeezy           700               OG               8.0
#
#     Release Date  Purchase Year           Designer Retail Price   Cost  \
# 0         2017.0           2017           Pharrell      £199.00  350.0
# 1         2017.0           2017                NaN      £120.00  120.0
# 2         2017.0           2017                NaN      £120.00  120.0
# 3         2021.0           2021               Clot      £120.00  195.0
# 4         2015.0           2019              Atmos      £120.00  270.0
# ..           ...            ...                ...          ...    ...
# 59           NaN           2016                NaN      £130.00   35.0
# 60           NaN           2016                NaN       £60.00   35.0
# 61        2019.0           2019  Comme des Garcons       £90.00   81.0
# 62        2019.0           2019  Comme des Garcons       £90.00   81.0
# 63        2015.0           2021                NaN      £250.00  250.0
#
#    Secondary Market Price (UK8 Stock X)
# 0                               £301.00
# 1                               £290.00
# 2                               £356.00
# 3                               £108.00
# 4                               £964.00
# ..                                  ...
# 59                               £89.00
# 60                               £52.00
# 61                              £123.00
# 62                              £130.00
# 63                              £320.00
#
# [64 rows x 10 columns]

# %%
trainers["Retail Price"] = trainers["Retail Price"].str.replace("£","").astype(float)

# %%
trainers.head(100)
# Out:
#           Brand         Model           Colour  Shoe Size (UK 8)  \
# 0        Adidas           NMD         Sun Glow               8.0
# 1          Nike    Air Max 1       Varsity Red               8.0
# 2          Nike    Air Max 1   University Blue               8.0
# 3          Nike    Air Max 1     Kiss of Death               8.0
# 4          Nike    Air Max 1    Atmos Elephant               8.0
# ..          ...           ...              ...               ...
# 59  New Balance           997            Multi               7.0
# 60         Vans        SK8 HI            Black               8.0
# 61     Converse  Chuck Taylor            Black               8.0
# 62          NaN  Chuck Taylor            White               8.0
# 63        Yeezy           700               OG               8.0
#
#     Release Date  Purchase Year           Designer  Retail Price   Cost  \
# 0         2017.0           2017           Pharrell         199.0  350.0
# 1         2017.0           2017                NaN         120.0  120.0
# 2         2017.0           2017                NaN         120.0  120.0
# 3         2021.0           2021               Clot         120.0  195.0
# 4         2015.0           2019              Atmos         120.0  270.0
# ..           ...            ...                ...           ...    ...
# 59           NaN           2016                NaN         130.0   35.0
# 60           NaN           2016                NaN          60.0   35.0
# 61        2019.0           2019  Comme des Garcons          90.0   81.0
# 62        2019.0           2019  Comme des Garcons          90.0   81.0
# 63        2015.0           2021                NaN         250.0  250.0
#
#    Secondary Market Price (UK8 Stock X)
# 0                               £301.00
# 1                               £290.00
# 2                               £356.00
# 3                               £108.00
# 4                               £964.00
# ..                                  ...
# 59                               £89.00
# 60                               £52.00
# 61                              £123.00
# 62                              £130.00
# 63                              £320.00
#
# [64 rows x 10 columns]

# %%
trainers["Designer"].value_counts()
# Out:
# Comme des Garcons    3
# Atmos                2
# Sacai                2
# Virgil               2
# Kendrick Lamar       1
# Clot                 1
# Denham               1
# Pharrell             1
# Undefeated           1
# Patta                1
# Sean Wotherspoon     1
# Size?                1
# Name: Designer, dtype: int64

# %%
print(trainers["Colour"])
# Out:
# 0            Sun Glow
# 1         Varsity Red
# 2     University Blue
# 3       Kiss of Death
# 4      Atmos Elephant
#            ...
# 59              Multi
# 60              Black
# 61              Black
# 62              White
# 63                 OG
# Name: Colour, Length: 64, dtype: object

# %%
trainers.head(5)
# Out:
#     Brand       Model           Colour  Shoe Size (UK 8)  Release Date  \
# 0  Adidas         NMD         Sun Glow               8.0        2017.0
# 1    Nike  Air Max 1       Varsity Red               8.0        2017.0
# 2    Nike  Air Max 1   University Blue               8.0        2017.0
# 3    Nike  Air Max 1     Kiss of Death               8.0        2021.0
# 4    Nike  Air Max 1    Atmos Elephant               8.0        2015.0
#
#    Purchase Year  Designer  Retail Price   Cost  \
# 0           2017  Pharrell         199.0  350.0
# 1           2017       NaN         120.0  120.0
# 2           2017       NaN         120.0  120.0
# 3           2021      Clot         120.0  195.0
# 4           2019     Atmos         120.0  270.0
#
#   Secondary Market Price (UK8 Stock X)
# 0                              £301.00
# 1                              £290.00
# 2                              £356.00
# 3                              £108.00
# 4                              £964.00

# %%
trainers["Secondary Market Price (UK8 Stock X)"] = trainers["Secondary Market Price (UK8 Stock X)"].str.replace(",","").str.replace("£","").astype(float)

# %%
trainers.head(10)
# Out:
#     Brand       Model           Colour  Shoe Size (UK 8)  Release Date  \
# 0  Adidas         NMD         Sun Glow               8.0        2017.0
# 1    Nike  Air Max 1       Varsity Red               8.0        2017.0
# 2    Nike  Air Max 1   University Blue               8.0        2017.0
# 3    Nike  Air Max 1     Kiss of Death               8.0        2021.0
# 4    Nike  Air Max 1    Atmos Elephant               8.0        2015.0
# 5    Nike  Air Max 1             Multi               8.0        2018.0
# 6    Nike  Air Max 1        Watermelon               8.0        2018.0
# 7    Nike  Air Max 1            Master               8.0        2017.0
# 8    Nike  Air Max 1            Orange               8.0        2021.0
# 9    Nike  Air Max 1              Aqua               8.0        2018.0
#
#    Purchase Year          Designer  Retail Price   Cost  \
# 0           2017          Pharrell        199.00  350.0
# 1           2017               NaN        120.00  120.0
# 2           2017               NaN        120.00  120.0
# 3           2021              Clot        120.00  195.0
# 4           2019             Atmos        120.00  270.0
# 5           2018  Sean Wotherspoon        124.99  300.0
# 6           2019               NaN        100.00  130.0
# 7           2019               NaN         89.99  296.0
# 8           2021             Patta        145.99  245.0
# 9           2017               NaN         99.95   50.0
#
#    Secondary Market Price (UK8 Stock X)
# 0                                 301.0
# 1                                 290.0
# 2                                 356.0
# 3                                 108.0
# 4                                 964.0
# 5                                 950.0
# 6                                 338.0
# 7                                 715.0
# 8                                 235.0
# 9                                 289.0

# %%
trainers["Price difference"] = trainers["Secondary Market Price (UK8 Stock X)"] - trainers ["Cost"]

# %%
trainers.describe()
# Out:
#        Shoe Size (UK 8)  Release Date  Purchase Year  Retail Price  \
# count         64.000000     61.000000      64.000000     64.000000
# mean           7.835938   2018.491803    2018.875000    127.791875
# std            0.252836      2.078645       1.759329     34.552246
# min            7.000000   2010.000000    2012.000000     60.000000
# 25%            7.500000   2017.000000    2018.000000     98.712500
# 50%            8.000000   2019.000000    2019.000000    124.990000
# 75%            8.000000   2020.000000    2020.000000    149.492500
# max            8.000000   2021.000000    2021.000000    250.000000
#
#              Cost  Secondary Market Price (UK8 Stock X)  Price difference
# count   64.000000                             64.000000         64.000000
# mean   138.872344                            316.311719        177.439375
# std     76.882194                            279.620843        260.157271
# min     35.000000                             52.000000        -87.000000
# 25%     87.750000                            137.500000         45.000000
# 50%    127.500000                            263.500000        100.500000
# 75%    165.000000                            353.000000        213.000000
# max    350.000000                           1816.000000       1726.000000

# %%
trainers["Price difference"] > 0
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4      True
#       ...
# 59     True
# 60     True
# 61     True
# 62     True
# 63     True
# Name: Price difference, Length: 64, dtype: bool

# %%
sum(trainers["Price difference"] > 0)
# Out:
# 56

# %%
import matplotlib.pyplot as plt

n, bins, patches = plt.hist(trainers["Price difference"])

plt.xlabel('Difference in Price')
plt.ylabel('Frequency')
plt.title('Histogram of Price Differences')
# Out:
# Text(0.5, 1.0, 'Histogram of Price Differences')

# %%
trainers.head()
# Out:
#     Brand       Model           Colour  Shoe Size (UK 8)  Release Date  \
# 0  Adidas         NMD         Sun Glow               8.0        2017.0
# 1    Nike  Air Max 1       Varsity Red               8.0        2017.0
# 2    Nike  Air Max 1   University Blue               8.0        2017.0
# 3    Nike  Air Max 1     Kiss of Death               8.0        2021.0
# 4    Nike  Air Max 1    Atmos Elephant               8.0        2015.0
#
#    Purchase Year  Designer  Retail Price   Cost  \
# 0           2017  Pharrell         199.0  350.0
# 1           2017       NaN         120.0  120.0
# 2           2017       NaN         120.0  120.0
# 3           2021      Clot         120.0  195.0
# 4           2019     Atmos         120.0  270.0
#
#    Secondary Market Price (UK8 Stock X)  Price difference
# 0                                 301.0             -49.0
# 1                                 290.0             170.0
# 2                                 356.0             236.0
# 3                                 108.0             -87.0
# 4                                 964.0             694.0

# %%
x=trainers["Cost"]
y=trainers["Secondary Market Price (UK8 Stock X)"]



plt.scatter(x,y)

plt.xlabel('Cost')
plt.ylabel('Seconday market price')
plt.title('Scatter graph of price change')

plt.xlim(0,1800)
plt.ylim(0,1850)
plt.axline((0,0),(1,1))

# %%
trainers["Years owned"] = 2021 - trainers["Purchase Year"] + 1

# %%
trainers["Price rate"]=trainers["Price difference"] / trainers["Years owned"]

# %%
n, bins, patches = plt.hist(trainers["Price rate"])

plt.xlabel('Raate of difference in price')
plt.ylabel('Frequency')
plt.title('Histogram of rate of price Differences')
# Out:
# Text(0.5, 1.0, 'Histogram of rate of price Differences')

# %%
trainers.head(5)
# Out:
#     Brand       Model           Colour  Shoe Size (UK 8)  Release Date  \
# 0  Adidas         NMD         Sun Glow               8.0        2017.0
# 1    Nike  Air Max 1       Varsity Red               8.0        2017.0
# 2    Nike  Air Max 1   University Blue               8.0        2017.0
# 3    Nike  Air Max 1     Kiss of Death               8.0        2021.0
# 4    Nike  Air Max 1    Atmos Elephant               8.0        2015.0
#
#    Purchase Year  Designer  Retail Price   Cost  \
# 0           2017  Pharrell         199.0  350.0
# 1           2017       NaN         120.0  120.0
# 2           2017       NaN         120.0  120.0
# 3           2021      Clot         120.0  195.0
# 4           2019     Atmos         120.0  270.0
#
#    Secondary Market Price (UK8 Stock X)  Price difference  Years owned  \
# 0                                 301.0             -49.0            5
# 1                                 290.0             170.0            5
# 2                                 356.0             236.0            5
# 3                                 108.0             -87.0            1
# 4                                 964.0             694.0            3
#
#    Price rate
# 0   -9.800000
# 1   34.000000
# 2   47.200000
# 3  -87.000000
# 4  231.333333

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as panda
import numpy as np

# %%
from sklearn import linear_model
#Create linear regression object
regr = linear_model.LinearRegression()
x=trainers["Cost"].values.reshape(-1, 1)
y=trainers["Secondary Market Price (UK8 Stock X)"]
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)

plt.xlabel('Cost')
plt.ylabel('Seconday market price')
plt.title('Scatter graph of price change')
x_min = 0 
x_max = 400
y_pred = regr.predict(np.array([x_min, x_max]).reshape(-1,1))
y_min = y_pred[0]
y_max = y_pred[1]
plt.axline((x_min,y_min),(x_max,y_max))

# %%
print("Coefficients: \n", regr.coef_)
# Out:
# Coefficients:
#  [1.38870225]

# %%
print("intercept: \n", regr.intercept_)
# Out:
# intercept:
#  123.4593825466767

# %%
trainers.head()
# Out:
#     Brand       Model           Colour  Shoe Size (UK 8)  Release Date  \
# 0  Adidas         NMD         Sun Glow               8.0        2017.0
# 1    Nike  Air Max 1       Varsity Red               8.0        2017.0
# 2    Nike  Air Max 1   University Blue               8.0        2017.0
# 3    Nike  Air Max 1     Kiss of Death               8.0        2021.0
# 4    Nike  Air Max 1    Atmos Elephant               8.0        2015.0
#
#    Purchase Year  Designer  Retail Price   Cost  \
# 0           2017  Pharrell         199.0  350.0
# 1           2017       NaN         120.0  120.0
# 2           2017       NaN         120.0  120.0
# 3           2021      Clot         120.0  195.0
# 4           2019     Atmos         120.0  270.0
#
#    Secondary Market Price (UK8 Stock X)  Price difference  Years owned  \
# 0                                 301.0             -49.0            5
# 1                                 290.0             170.0            5
# 2                                 356.0             236.0            5
# 3                                 108.0             -87.0            1
# 4                                 964.0             694.0            3
#
#    Price rate
# 0   -9.800000
# 1   34.000000
# 2   47.200000
# 3  -87.000000
# 4  231.333333

# %%
assert (trainers["Shoe Size (UK 8)"] < 9).all(), "Atleast one pair of shoes is size 9 or above"

# %%
assert (trainers["Shoe Size (UK 8)"] > 7).all(), "Atleast one pair of shoes is size 7 or below"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16836/1051889460.py in <module>
# ----> 1 assert (trainers["Shoe Size (UK 8)"] > 7).all(), "Atleast one pair of shoes is size 7 or below"
#
# AssertionError: Atleast one pair of shoes is size 7 or below
